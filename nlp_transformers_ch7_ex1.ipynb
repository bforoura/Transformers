# %% [markdown]
# <a href="https://colab.research.google.com/github/bforoura/Transformers/blob/main/nlp_transformers_ch7_ex1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#@title Install Hugging Face's transformers

# !pip install transformers==4.11.3

# %%
#@title Install SentencePiece, a subword tokenizer and detokenizer for NLP.

# !pip install sentencepiece==0.1.94
# !pip install 'lightning-flash[text]' --upgrade

# %%
#@title Display the architecture of the model.

display_architecture=True

# %%
#@title The tokenizer, generation, and configuration classes.


import torch
import json 
from transformers import T5Tokenizer, T5ForConditionalGeneration, T5Config

model = T5ForConditionalGeneration.from_pretrained('t5-large')
tokenizer = T5Tokenizer.from_pretrained('t5-large')
device = torch.device('cpu')
# Out:
# Downloading:   0%|          | 0.00/1.17k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/2.75G [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/773k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.32M [00:00<?, ?B/s]
